# %% [markdown]
# # Analysis of LLM Responses to Smith Case
#
# This notebook samples responses from different LLM models regarding the Smith case.

# %%
import pandas as pd
import random
random.seed(42)  # For reproducibility

# %%
# Function to load and sample from CSV files
def load_and_sample(file_path, n_samples=5):
    df = pd.read_csv(file_path)
    return df.sample(n=n_samples, random_state=42)

# %%
# List of files to process
files = [
    '../data/smith_responses_gemini_3_1_flash_lite.csv',
    '../data/smith_responses_claude_opus_4_7.csv',
    '../data/smith_responses_gpt_5_5.csv'
]

# Dictionary to store samples
all_samples = {}

# Load samples from each file
for file in files:
    model_name = file.split('/')[-1].replace('smith_responses_', '').replace('.csv', '')
    all_samples[model_name] = load_and_sample(file)

# %%
# Create a markdown formatted output
for model, samples in all_samples.items():
    print(f"## Samples from {model}\n")
    for idx, row in samples.iterrows():
        print(f"### Sample {idx + 1}")
        print(f"**Answer:** {row['answer']}\n")
        print(f"**Reasoning:**\n{row['reasoning']}\n")
        print("-" * 80 + "\n")
# Out:
# ## Samples from gemini_3_1_flash_lite
#
# ### Sample 84
# **Answer:** Yes
#
# **Reasoning:**
# As an ordinary person, I look at the word "use" in the context of a drug crime and ask if the gun played an active role in the transaction. In this case, Mr. Smith didn't just carry the gun in his pocket or keep it in a closet; he specifically brought it out to use as currency. He treated the MAC-10 as a piece of property to be traded for cocaine. By offering the firearm as payment to secure the drugs, he "used" the weapon as a tool to facilitate the drug deal. Even though he didn't fire the gun or point it at someone in a threatening way, he utilized its value as a commodity to complete his criminal objective. Therefore, it seems clear that he "used" the firearm in relation to a drug trafficking crime.
#
# --------------------------------------------------------------------------------
#
# ### Sample 54
# **Answer:** Yes
#
# **Reasoning:**
# As an ordinary person, I look at the word "use" in the context of a drug crime. While we typically think of "using" a gun as firing it or pointing it at someone to threaten them, the situation here is different: the petitioner was actively using the gun as a form of currency. By offering the MAC-10 as a direct trade for cocaine, he was utilizing the weapon as a tool to facilitate the drug deal. Because he was essentially "spending" the gun to acquire drugs, he was relying on its value as a weapon to conduct his illegal business. If he hadn't had the gun to offer in exchange, the specific transaction he was proposing to the undercover officer could not have taken place. Therefore, it seems reasonable to conclude that he "used" the firearm to further his drug trafficking activity.
#
# --------------------------------------------------------------------------------
#
# ### Sample 71
# **Answer:** Yes
#
# **Reasoning:**
# As an ordinary person, I interpret the word "use" in a broad sense. While one might typically think of "using" a gun to shoot it, in the context of a drug trafficking crime, using a gun can also mean employing it as a tool or a commodity to facilitate a deal. In this case, Mr. Smith didn't just have the gun in his possession; he actively pulled it out and offered it as a specific item of value to trade for cocaine. By offering the MAC-10 as a form of currency to complete a drug transaction, he effectively made the firearm a functional part of the crime itself. Therefore, it seems reasonable to conclude that he "used" the firearm to further his illegal drug activity.
#
# --------------------------------------------------------------------------------
#
# ### Sample 46
# **Answer:** Yes
#
# **Reasoning:**
# From an ordinary perspective, the word "use" generally refers to employing something to accomplish a specific purpose or goal. In this case, Mr. Smith did not just possess the gun or have it sitting in a bag; he actively pulled it out and offered it as a specific item of barter to trade for drugs. By using the firearm as a currency or an object of exchange to facilitate his drug trafficking crime, he was clearly "using" the weapon to further his criminal objective. Even though he wasn't firing the gun, he was utilizing its value as a tool to complete the illegal transaction, which fits the common-sense understanding that he made "use" of the firearm during the commission of a drug crime.
#
# --------------------------------------------------------------------------------
#
# ### Sample 45
# **Answer:** Yes
#
# **Reasoning:**
# As an ordinary person looking at this situation, "using" a gun typically implies employing it to achieve a goal. In this case, Mr. Smith did not just carry the gun or keep it hidden in a bag; he actively pulled it out and offered it as a specific item of barter to trade for drugs. By making the firearm the currency of his drug deal, he transformed it from a piece of property into an active tool used to facilitate the crime. Even though he wasn't firing the weapon, he was clearly utilizing its value as a weapon to conduct his illegal narcotics transaction. Therefore, it makes sense to conclude that he "used" the gun in relation to a drug trafficking crime.
#
# --------------------------------------------------------------------------------
#
# ## Samples from claude_opus_4_7
#
# ### Sample 84
# **Answer:** No
#
# **Reasoning:**
# When most regular people hear that someone "used a firearm" during a drug crime, they think of someone using it as a weapon — threatening, shooting, or brandishing it to protect a drug deal. Smith didn't do any of that. He treated his MAC-10 like a piece of merchandise he wanted to trade for cocaine, similar to how someone might trade a TV or a watch. Even though the gun was involved in the drug deal, he wasn't "using" it the way the statute seems to be talking about. The law appears aimed at the extra danger created when guns are used as weapons during drug crimes, not at people bartering guns for drugs.
#
# --------------------------------------------------------------------------------
#
# ### Sample 54
# **Answer:** No
#
# **Reasoning:**
# When ordinary people talk about "using a gun," they almost always mean using it as a weapon - firing it, pointing it, or threatening someone with it. In this case, Smith wasn't using the gun as a weapon at all. He was treating it like merchandise or currency, offering to trade it for drugs. That's more like selling a gun than using one. If someone asked me, "Did he use a gun in the drug deal?" I'd naturally answer no, because he was trying to swap it for cocaine, not threaten anyone or fire it. Trading something is different from using it in the everyday sense of the word.
#
# --------------------------------------------------------------------------------
#
# ### Sample 71
# **Answer:** No
#
# **Reasoning:**
# When regular people hear "used a gun" during a drug crime, they think of someone pointing it, firing it, or threatening someone with it—using it as a weapon. Mr. Smith wasn't using his MAC-10 as a weapon at all. He was treating it like an item to barter, basically using it as money to buy cocaine. That's more like trading or selling the gun than "using" it. If I traded my car for drugs, you wouldn't say I "used my car" in the drug deal in any meaningful sense—I just sold it. The law seems aimed at punishing people who make drug crimes more dangerous by bringing weapons into them, and Smith's gun, sitting in a bag and then being handed over as merchandise, didn't make the situation more dangerous in that way.
#
# --------------------------------------------------------------------------------
#
# ### Sample 46
# **Answer:** No
#
# **Reasoning:**
# When ordinary people hear that someone "used a gun" during a drug crime, they think of the gun being used as a weapon - shooting it, pointing it, threatening someone, or having it ready for protection or intimidation. In this case, Smith didn't use the gun as a weapon at all. He was trying to trade it away like a piece of merchandise in exchange for cocaine. The gun was the item being sold, not a tool used to commit the crime. It's like saying someone "used" their car during a drug deal because they traded it for drugs - that's not really what "use" means in normal speech when we're talking about firearms in criminal activity. So while Smith did something with the gun, he didn't "use" it in the way the statute seems to be talking about.
#
# --------------------------------------------------------------------------------
#
# ### Sample 45
# **Answer:** No
#
# **Reasoning:**
# When ordinary people say someone "used a gun" during a crime, they mean used it as a weapon — to shoot, threaten, or intimidate. Smith didn't do any of those things. He treated the gun like merchandise, trading it as if it were money to get cocaine. Bartering an object isn't the same as "using" it in the way we normally understand that phrase when talking about guns and crimes. If he had pointed it at the officer or fired it, that would clearly be "use." But simply offering to swap it for drugs is more like selling a possession than using a weapon.
#
# --------------------------------------------------------------------------------
#
# ## Samples from gpt_5_5
#
# ### Sample 84
# **Answer:** Yes
#
# **Reasoning:**
# An ordinary person would likely say Mr. Smith “used” the gun because he did more than just possess it. He brought it out, showed it to the undercover officer, and offered to trade it for cocaine. In that situation, the gun was being used as an item of value to help get drugs. Even though he did not fire it or threaten anyone with it, he was using the gun as part of a drug deal, which fits the statute’s idea of using a firearm during and in relation to a drug trafficking crime.
#
# --------------------------------------------------------------------------------
#
# ### Sample 54
# **Answer:** Yes
#
# **Reasoning:**
# Mr. Smith did more than just possess the gun. He brought it into a drug deal, showed it to the undercover officer, and offered to trade it for cocaine. Even though he did not fire it or threaten anyone with it, he was still using the gun as something valuable to get drugs. An ordinary person could understand that as “using” the gun during and in relation to a drug trafficking crime because the gun was part of the deal.
#
# --------------------------------------------------------------------------------
#
# ### Sample 71
# **Answer:** Yes
#
# **Reasoning:**
# Mr. Smith did more than merely possess the gun. He brought it out, showed it to the undercover officer, and offered to trade it for cocaine. In ordinary terms, he was using the gun as a bargaining tool or payment in a drug deal. Even though he did not fire it, threaten anyone with it, or carry it as protection, he still put the gun to practical use to try to obtain drugs. So a reasonable person could say he “used” the gun during and in relation to a drug trafficking crime.
#
# --------------------------------------------------------------------------------
#
# ### Sample 46
# **Answer:** Yes
#
# **Reasoning:**
# An ordinary person could reasonably say Mr. Smith “used” the gun because he was not just storing it or casually possessing it. He brought it out, showed it, and offered it as payment to get cocaine. In simple terms, he was using the gun as a bargaining tool in a drug deal. Even though he did not fire it or threaten anyone with it, he put the gun to use to try to obtain drugs, so it fits the statute’s language.
#
# --------------------------------------------------------------------------------
#
# ### Sample 45
# **Answer:** Yes
#
# **Reasoning:**
# Mr. Smith did more than just have the gun nearby. He took it out, showed it to the undercover officer, and offered to trade it for cocaine. In ordinary language, that seems like “using” the gun because he was using it as something valuable to get drugs, like using money or property in a deal. Even though he did not fire it or threaten anyone with it, the gun was an active part of the drug transaction. So a reasonable person could say he “used” the gun during and in relation to a drug trafficking crime.
#
# --------------------------------------------------------------------------------

# %%
# Save samples to a markdown file for easier reading
with open('../data/sample_responses_2026.md', 'w') as f:
    f.write("# Sample Responses from Different Models\n\n")
    for model, samples in all_samples.items():
        f.write(f"## Samples from {model}\n\n")
        for idx, row in samples.iterrows():
            f.write(f"### Sample {idx + 1}\n")
            f.write(f"**Answer:** {row['answer']}\n\n")
            f.write(f"**Reasoning:**\n{row['reasoning']}\n\n")
            f.write("-" * 80 + "\n\n")

# %%
#Retrieve the only answer "No" from the smith_responses_gpt_4o.csv file
# Kept as is, because there are now a majority of responses with "No" from Claude Opus 4.7, so we want to keep the code to retrieve the reasoning for the "No" answer from GPT-4o as well, for comparison.

from IPython.display import display, Markdown
file = '../data/smith_responses_gpt_4o.csv'
# Read the CSV file
df = pd.read_csv(file)

# Find the row where answer is "No"
no_response = df[df['answer'] == 'No']

# Display the reasoning as markdown if there is a "No" answer
if not no_response.empty:
    reasoning = no_response['reasoning'].iloc[0]
    display(Markdown(reasoning))
else:
    print("No 'No' responses found in the file")
# Out:
# As an average person looking at this situation, the term "use" of a firearm in the statute likely means actually employing it as a weapon in connection with a crime, such as threatening someone with it or firing it. In the case summary, Mr. Smith's actions involved: (1) discussing the gun with a drug dealer, (2) showing the gun to an undercover officer, and (3) offering to trade the gun for drugs. While these actions do demonstrate that Mr. Smith was involved in illegal activity related to the gun, he didn't actually brandish, fire, or explicitly threaten someone with it. He was trying to use the gun as a bargaining chip in a drug deal, which is certainly criminal, but it doesn't seem like what an ordinary person would think of as "using" a gun to commit a crime of violence or drug trafficking crime, as implied by the statute. A reasonable person might think that "using" a gun during a crime means directly employing it as a weapon, not just showing it or offering it in a trade.
